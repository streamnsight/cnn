# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# --------------

# %% [markdown]
# # If it's written in Python with scikit-learn, it's probably Machine Learning
#
# # If it's written in Python with TensorFlow or PyTorch, it's probably some sort of Neural Network
